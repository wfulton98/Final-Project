# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data loading and exploratory analysis

# %%
#read in the data set
#consists of 1.5 million million reviews 
df = pd.read_csv("beer_reviews.csv")
df.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# ...

# %%
unique_breweries = df['brewery_id'].unique()
unique_reviewers = df['review_profilename'].unique()
unique_styles = df['beer_style'].unique()
unique_beers = df['beer_beerid'].unique()

print(f"There are {len(unique_breweries)} unique breweries.")
print(f"{len(unique_reviewers)} unique reviewers.")
print(f"{len(unique_styles)} unique beers styles.")
print(f"{len(unique_beers)} unique beers.\n")
print(df.shape)
# Out:
# There are 5840 unique breweries.
# 33388 unique reviewers.
# 104 unique beers styles.
# 66055 unique beers.
#
# (1586614, 13)

# %%
#Change review_time to datetime
df['review_time'] = pd.to_datetime( df['review_time'], unit='s')
df.head()
# Out:
#    brewery_id             brewery_name         review_time  review_overall  \
# 0       10325          Vecchio Birraio 2009-02-16 20:57:03             1.5
# 1       10325          Vecchio Birraio 2009-03-01 13:44:57             3.0
# 2       10325          Vecchio Birraio 2009-03-01 14:10:04             3.0
# 3       10325          Vecchio Birraio 2009-02-15 19:12:25             3.0
# 4        1075  Caldera Brewing Company 2010-12-30 18:53:26             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# ...

# %%
group_by_date = df[['review_time']].groupby( df['review_time'].dt.date ).agg(['count'])

plt.figure(figsize=(20,5))
plt.plot(group_by_date)
plt.xlabel('Date')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews per Day')
plt.show()

# %%
#data analysis based on beer style
beer_styles = df[['beer_style']]
beer_styles['beer_style'].value_counts(dropna=False).head()
# Out:
# American IPA                        117586
# American Double / Imperial IPA       85977
# American Pale Ale (APA)              63469
# Russian Imperial Stout               54129
# American Double / Imperial Stout     50705
# Name: beer_style, dtype: int64

# %%
#group beer styles into average overall ratings and count
beer_styles = df.groupby(['beer_style'])
beer_styles = beer_styles.mean()
beer_styles = beer_styles.reset_index()
fig, ax = plt.subplots(figsize=(8,6))
x = range(1,6)
counts = np.zeros(5)
for val in beer_styles['review_overall']:
    if val < 2:
        counts[0] += 1
    elif val < 3:
        counts[1] += 1
    elif val < 4:
        counts[2] += 1
    elif val < 5:
        counts[3] += 1
    else:
        counts[4] += 1
        
ax.bar(x, counts)
ax.set_xlabel('Average rating')
ax.set_ylabel('Number of Styles')
ax.set_title('Occurrences of Average Overall Ratings for Beer Styles')
plt.show()

print(counts)
# Out:
# [ 0.  5. 92.  7.  0.]

# %%
#find lowest and highest rated beers
sorted_beer_styles = beer_styles.sort_values('review_overall')
print(np.mean(sorted_beer_styles['review_overall']))
lowest_rated_style = [list(sorted_beer_styles['beer_style'])[0], list(sorted_beer_styles['review_overall'])[0]]
highest_rated_style = [list(sorted_beer_styles['beer_style'])[-1], list(sorted_beer_styles['review_overall'])[-1]]

print(f"Highest rated beer style: {highest_rated_style[0]} ({np.round(highest_rated_style[1], 4)})")
print(f"Lowest rated beer style: {lowest_rated_style[0]} ({np.round(lowest_rated_style[1], 4)})")
# Out:
# 3.7322314309124085
# Highest rated beer style: American Wild Ale (4.0933)
# Lowest rated beer style: Low Alcohol Beer (2.5783)

# %%
breweries = df.groupby(['brewery_name'])
breweries = breweries.mean()
breweries = breweries.reset_index()
fig, ax = plt.subplots(figsize=(8,6))
x = range(1,6)
counts = np.zeros(5)
for val in breweries['review_overall']:
    if val < 2:
        counts[0] += 1
    elif val < 3:
        counts[1] += 1
    elif val < 4:
        counts[2] += 1
    elif val < 5:
        counts[3] += 1
    else:
        counts[4] += 1


ax.bar(x, counts)
ax.set_xlabel('Average rating')
ax.set_ylabel('Number of breweries')
ax.set_title('Occurrences of Average Overall Ratings for Breweries')
plt.show()
breweries.head()
# Out:
#               brewery_name  brewery_id  review_overall  review_aroma  \
# 0        't Hofbrouwerijke     13160.0        3.702703      3.783784
# 1    (512) Brewing Company     17863.0        4.065789      4.001645
# 2    10 Barrel Brewing Co.     16873.0        3.732143      3.571429
# 3     1516 Brewing Company      4473.0        4.132353      3.911765
# 4  16 Mile Brewing Company     20688.0        3.570652      3.402174
#
#    review_appearance  review_palate  review_taste  beer_abv   beer_beerid
# 0           3.851351       3.540541      3.621622  6.789189  35306.864865
# 1           4.057566       3.958882      4.055921  7.149662  51099.884868
# 2           3.815476       3.619048      3.636905  6.066667  55452.488095
# 3           4.191176       3.897059      4.073529  6.266667  38128.000000
# 4           3.766304       3.614130      3.472826  6.033696  55400.184783

# %%
print('Average overall review: ', np.round(np.mean(df['review_overall']),4))
print('Total number of breweries for each rating: ', counts)
# Out:
# Average overall review:  3.8156
# Total number of breweries for each rating:  [  78.  641. 4009.  993.   21.]

# %%
breweries_sorted = breweries.sort_values('review_overall')
#print(breweries_sorted.head(),'\n')
lowest_rated_style = [list(breweries_sorted['brewery_name'])[0], list(breweries_sorted['review_overall'])[0]]
highest_rated_style = [list(breweries_sorted['brewery_name'])[-1], list(breweries_sorted['review_overall'])[-1]]
print(f"Highest rated brewery: {highest_rated_style[0]} ({highest_rated_style[1]})")
print(f"Lowest rated brewery: {lowest_rated_style[0]} ({lowest_rated_style[1]})")
# Out:
# Highest rated brewery: Elizabeth Street Brewery (5.0)
# Lowest rated brewery: Red Dot Brewhouse (1.0)

# %% [markdown]
# These preliminary results give us a better understanding of our data and the general type of reviews that were given. Now that we know them we are going to attempt to use collaborative filtering to generate profile reccomendations based on the data.

# %% [markdown]
# # Collaborative Filtering
# ### We will be using only the first 200,000 data points for the sake of memory and runt time
#
# Our first reccomendation model will be build off of collaboritive filtering

# %%
#grab the first 200,000 data points
df_new = df[:200000]
print(len(df_new))

unique_breweries = df_new['brewery_id'].unique()
unique_reviewers = df_new['review_profilename'].unique()
unique_styles = df_new['beer_style'].unique()
unique_beers = df_new['beer_beerid'].unique()

print(f"There are {len(unique_breweries)} unique breweries.")
print(f"{len(unique_reviewers)} unique reviewers.")
print(f"{len(unique_styles)} unique beers styles.")
print(f"{len(unique_beers)} unique beers.\n")
print(df.shape)
# Out:
# 200000
# There are 767 unique breweries.
# 15482 unique reviewers.
# 103 unique beers styles.
# 8258 unique beers.
#
# (1586614, 13)

# %% [markdown]
# ### Build a col. filtering matrix based on beer styles against users overall review

# %%
beer_styles_df = df_new.groupby(['review_profilename', 'beer_style'])
beer_styles_df.first()
# Out:
#                                                         brewery_id  \
# review_profilename beer_style
# 0110x011           American Amber / Red Ale                   5318
#                    American Barleywine                         396
#                    American Double / Imperial IPA             3818
#                    American Double / Imperial Pilsner         5318
#                    American Double / Imperial Stout           1199
# ...                                                            ...
# zymurgy4all        Rauchbier                                   263
#                    Vienna Lager                              14551
# zymurgywhiz        American IPA                                140
# zythus             Extra Special / Strong Bitter (ESB)         140
# zyzygy             Altbier                                      94
#
#                                                                                         brewery_name  \
# ...

# %%
#build matrix
profile_names = df_new['review_profilename'].unique()
beer_styles = df_new['beer_style'].unique()
print(len(profile_names))
print(len(beer_styles))

#our matrix will consist of users as the columns and beer_styles (items) as the rows
#initialize an empty matrix of size (items, users) 
ratings_style = np.empty((len(beer_styles), len(profile_names)))
ratings_style[:] = np.NaN
print(ratings_style.shape)
# Out:
# 15482
# 103
# (103, 15482)

# %%
num_reviews = 0
num_blank_reviews = 0
for idx, style in enumerate(beer_styles):
    for jdx, name in enumerate(profile_names):
        #see if the review exists
        try:
            review = beer_styles_df.get_group( (name, style) )[ 'review_overall' ]
            num_reviews += 1
        
            if len(review) > 1:
                review = np.mean( review )
                ratings_style[ idx, jdx ] = review
            else:
                ratings_style[ idx, jdx ] = review
                
        except:
            num_blank_reviews += 1
            continue #leave entry as NaN if the user has not reviewed

# %%
print(f'There are {num_reviews} total reviews for beer styles, and {num_blank_reviews} empty reviews.')
# Out:
# There are 105748 total reviews for beer styles, and 1488898 empty reviews.

# %%
#find the average number of ratings per user
num_user_ratings = []
for idx, name in enumerate(profile_names):
    user_ratings = ratings_style[ :, idx ]
    num_user_ratings.append( np.count_nonzero( ~np.isnan(user_ratings) ))
    
    
print(f'The average user has rated {np.round(np.mean(num_user_ratings), 4)} beer styles.')

#find the average number of ratings per item
num_item_ratings = []
for idx, style in enumerate(beer_styles):
    item_ratings = ratings_style[ idx, : ]
    num_item_ratings.append( np.count_nonzero( ~np.isnan(item_ratings) ))

print(f'The average beer style has been reviewed by {np.round(np.mean(num_item_ratings), 4)} users.')
# Out:
# The average user has rated 6.8304 beer styles.
# The average beer style has been reviewed by 1026.6796 users.

# %%
#create a data frame from the beer style rating matrix
df_style_ratings = pd.DataFrame(ratings_style)
df_style_ratings.rename(columns={ idx: name for idx, name in enumerate(profile_names) }, index={ idx: style for idx, style in enumerate(beer_styles)}, inplace=True)
df_style_ratings.head()
# Out:
#                                  stcules  johnmichaelsen  oline73  Reidrover  \
# Hefeweizen                      3.000000        3.750000   2.0000        3.5
# English Strong Ale              3.333333        4.250000      NaN        3.5
# Foreign / Export Stout          3.000000        4.000000      NaN        NaN
# German Pilsener                 3.071429        4.800000   4.0000        4.0
# American Double / Imperial IPA       NaN        3.515625   3.8125        3.5
#
#                                 alpinebryant  LordAdmNelson  augustgarage  \
# Hefeweizen                               NaN            NaN      4.375000
# English Strong Ale                       NaN            NaN           NaN
# Foreign / Export Stout                   NaN            NaN           NaN
# German Pilsener                          NaN            NaN      4.000000
# American Double / Imperial IPA           3.5            4.0      3.888889
#
# ...

# %% [markdown]
# ### Build a collaborative filtering matrix based on brewery against users overall review

# %%
breweries_df = df_new.groupby(['review_profilename', 'brewery_name'])
breweries_df.first()
# Out:
#                                               brewery_id         review_time  \
# review_profilename brewery_name
# 0110x011           AleSmith Brewing Company          396 2009-07-01 05:37:44
#                    Bear Republic Brewing Co.         610 2009-06-05 00:10:34
#                    Brouwerij Verhaeghe               641 2008-06-25 17:23:12
#                    Founders Brewing Company         1199 2009-07-12 04:15:18
#                    Green Flash Brewing Co.          2743 2009-05-03 23:25:57
# ...                                                  ...                 ...
# zymurgy4all        Sierra Nevada Brewing Co.         140 2008-06-18 21:17:46
#                    Stoudts Brewing Co.               394 2008-03-01 00:17:14
# zymurgywhiz        Sierra Nevada Brewing Co.         140 2009-01-08 22:22:47
# zythus             Sierra Nevada Brewing Co.         140 2009-03-21 18:02:53
# zyzygy             Long Trail Brewing Co.             94 2006-02-03 23:13:01
#
# ...

# %%
#build matrix
#our matrix will consist of users as the columns and breweries (items) as the rows
#initialize an empty matrix of size (items, users) 
profile_names = df_new['review_profilename'].unique()
brewery_names = df_new['brewery_name'].unique()
print(len(profile_names))
print(len(brewery_names))

ratings = np.empty((len(brewery_names), len(profile_names)))
ratings[:] = np.NaN
print(ratings.shape)
# Out:
# 15482
# 765
# (765, 15482)

# %%
num_reviews = 0
num_blank_reviews = 0
for idx, brewery in enumerate(brewery_names):
    for jdx, name in enumerate(profile_names):
        #see if the review exists
        try:
            review = breweries_df.get_group( (name, brewery) )[ 'review_overall' ]
            num_reviews += 1
        
            if len(review) > 1:
                #if the user has reviewed the brewery multiple times, take the user's average rating of the brewery
                review = np.mean( review )
                ratings[ idx, jdx ] = review
            else:
                ratings[ idx, jdx ] = review
                
        except:
            num_blank_reviews += 1
            continue #leave entry as NaN if the user has not reviewed

# %%
print(f'There are {num_reviews} total reviews for beer styles, and {num_blank_reviews} empty reviews.')
# Out:
# There are 81404 total reviews for beer styles, and 11762326 empty reviews.

# %%
#find the average number of ratings per user
num_user_ratings = []
for idx, name in enumerate(profile_names):
    user_ratings = ratings[ :, idx ]
    num_user_ratings.append( np.count_nonzero( ~np.isnan(user_ratings) ))
    
    
print(f'The average user has rated {np.round(np.mean(num_user_ratings), 4)} breweries.')

#find the average number of ratings per item
num_item_ratings = []
for idx, brewery in enumerate(brewery_names):
    item_ratings = ratings[ idx, : ]
    num_item_ratings.append( np.count_nonzero( ~np.isnan(item_ratings) ))

print(f'The average brewery has been reviewed by {np.round(np.mean(num_item_ratings), 4)} users.')
# Out:
# The average user has rated 5.258 breweries.
# The average brewery has been reviewed by 106.4105 users.

# %%
df_brewery_ratings = pd.DataFrame(ratings)
df_brewery_ratings.rename(columns={ idx: name for idx, name in enumerate(profile_names) }, index={ idx: brewery for idx, brewery in enumerate(brewery_names)}, inplace=True)
print(df_brewery_ratings.shape)
df_brewery_ratings.head()
# Out:
# (765, 15482)
#                             stcules  johnmichaelsen  oline73  Reidrover  \
# Vecchio Birraio               2.625             NaN      NaN        NaN
# Caldera Brewing Company         NaN             4.0      3.0       3.75
# Amstel Brouwerij B. V.          NaN             NaN      NaN       3.00
# Broad Ripple Brew Pub           NaN             NaN      NaN        NaN
# Moon River Brewing Company      NaN             NaN      NaN        NaN
#
#                             alpinebryant  LordAdmNelson  augustgarage  \
# Vecchio Birraio                      NaN            NaN           NaN
# Caldera Brewing Company              3.0            4.0          4.25
# Amstel Brouwerij B. V.               NaN            NaN           NaN
# Broad Ripple Brew Pub                NaN            NaN           NaN
# Moon River Brewing Company           NaN            NaN           NaN
#
#                             fodeeoz  MadeInOregon  rawthar  ...  Stevoli  \
# ...

# %% [markdown]
# # Impute missing data

# %%
from sklearn.impute import KNNImputer
from sklearn.metrics.pairwise import cosine_similarity

# %%
imputer = KNNImputer(missing_values=np.nan, weights='distance') #default n_neighbors=5
fit_model_styles = imputer.fit_transform(df_style_ratings)

# %%
fit_style_ratings = pd.DataFrame(fit_model_styles)
fit_style_ratings.rename(columns={ idx: name for idx, name in enumerate(profile_names) }, index={ idx: style for idx, style in enumerate(beer_styles)}, inplace=True)
fit_style_ratings.head()
# Out:
#                                  stcules  johnmichaelsen   oline73  Reidrover  \
# Hefeweizen                      3.000000        3.750000  2.000000   3.500000
# English Strong Ale              3.333333        4.250000  3.868363   3.500000
# Foreign / Export Stout          3.000000        4.000000  3.922976   3.877902
# German Pilsener                 3.071429        4.800000  4.000000   4.000000
# American Double / Imperial IPA  3.035712        3.515625  3.812500   3.500000
#
#                                 alpinebryant  LordAdmNelson  augustgarage  \
# Hefeweizen                          4.252162       4.191751      4.375000
# English Strong Ale                  3.958940       4.142036      3.867870
# Foreign / Export Stout              3.904641       3.852083      3.850505
# German Pilsener                     3.951584       4.038598      4.000000
# American Double / Imperial IPA      3.500000       4.000000      3.888889
#
# ...

# %%
fit_model_breweries = imputer.fit_transform(df_brewery_ratings)
fit_brewery_ratings = pd.DataFrame(fit_model_breweries)
fit_brewery_ratings.rename(columns={ idx: name for idx, name in enumerate(profile_names) }, index={ idx: brewery for idx, brewery in enumerate(brewery_names)}, inplace=True)
fit_brewery_ratings.head()
# Out:
#                              stcules  johnmichaelsen   oline73  Reidrover  \
# Vecchio Birraio             2.625000        3.842885  3.819309   3.439730
# Caldera Brewing Company     3.000000        4.000000  3.000000   3.750000
# Amstel Brouwerij B. V.      2.663160        3.722865  3.568549   3.000000
# Broad Ripple Brew Pub       2.899167        4.055556  3.814182   4.000000
# Moon River Brewing Company  2.416667        4.155928  3.730577   3.878874
#
#                             alpinebryant  LordAdmNelson  augustgarage  \
# Vecchio Birraio                 3.773292       3.883979      4.219846
# Caldera Brewing Company         3.000000       4.000000      4.250000
# Amstel Brouwerij B. V.          3.228975       3.681952      3.690128
# Broad Ripple Brew Pub           4.071324       3.831569      3.500000
# Moon River Brewing Company      3.661838       4.110660      4.500000
#
#                              fodeeoz  MadeInOregon   rawthar  ...  \
# ...

# %%
old_mean = np.nanmean(df_brewery_ratings['Reidrover'])
new_mean = np.mean(fit_brewery_ratings['Reidrover'])
print(old_mean, new_mean)

num_ratings_old = np.count_nonzero( ~np.isnan(df_brewery_ratings['Reidrover']) )
num_ratings_new = np.count_nonzero( ~np.isnan(fit_brewery_ratings['Reidrover']) )
print(num_ratings_old, num_ratings_new)
print(min(fit_brewery_ratings['Reidrover']))
print(max(fit_brewery_ratings['Reidrover']))
# Out:
# 3.7195547377151152 3.707500510554203
# 53 765
# 1.0
# 4.5

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Compare means of breweries  before an after impute

# %%
original_breweries = df_brewery_ratings.T
imputed_breweries = fit_brewery_ratings.T

# %%
mean_brewery_comparison = np.ndarray((len(brewery_names), 3))
for idx, brewery in enumerate(brewery_names):
    old_mean = np.nanmean(original_breweries[brewery])
    new_mean = np.mean(imputed_breweries[brewery])
    change = np.abs(new_mean - old_mean)
    mean_brewery_comparison[idx, :] = (old_mean, new_mean, change)
    
df_brewery_mean = pd.DataFrame(mean_brewery_comparison, columns=['Old', 'Imputed', 'Change'])
df_brewery_mean.rename(index={idx: brewery for idx, brewery in enumerate(brewery_names)}, inplace=True)
df_brewery_mean.head()
# Out:
#                                  Old   Imputed    Change
# Vecchio Birraio             2.625000  3.910926  1.285926
# Caldera Brewing Company     3.978712  3.959418  0.019294
# Amstel Brouwerij B. V.      2.777512  3.831801  1.054288
# Broad Ripple Brew Pub       3.874213  3.929008  0.054795
# Moon River Brewing Company  3.769613  3.931794  0.162181

# %%
average_brewery_rating_change = np.mean(df_brewery_mean['Change'])
std_brewery_rating_change = np.std(df_brewery_mean['Change'])
max_brewery_rating_change = max(df_brewery_mean['Change'])
min_brewery_rating_change = min(df_brewery_mean['Change'])
print(f'The average rating change for all breweries was {np.round(average_brewery_rating_change, 4)} with a standard devation of {np.round(std_brewery_rating_change, 4)}')
print(f'The maximum rating change for all breweries was {np.round(max_brewery_rating_change, 4)}')
print(f'The minimum rating change for all breweries was {np.round(min_brewery_rating_change,4)}')
# Out:
# The average rating change for all breweries was 0.4743 with a standard devation of 0.4505
# The maximum rating change for all breweries was 2.4341
# The minimum rating change for all breweries was 0.0007

# %%
### find frequency of all breweries
freq = df_new[['brewery_name']].value_counts()
y = list(df_brewery_mean['Change'])
x = []
for brewery in df_brewery_mean.index:
    x.append(int(freq[brewery]))

# %%
plt.figure(figsize=(12,6))
plt.scatter(x, y, zorder=2)
plt.title("Difference in Mean Rating Change After Impute for Each Brewery Compared to Number of Reviews", fontsize=16)
plt.ylabel("Difference", fontsize=16)
plt.xlabel("Number of Reviews", fontsize=16)
plt.grid(zorder=0)

# %% [markdown]
# #### As we can see most, as any brewery gets more reviews the less its overall mean rating changes

# %% [markdown]
# ### Plot the distribution of brewery rating means before impute

# %%
old = df_brewery_mean['Old']
sigma = np.std(old)

plt.figure(figsize=(12,6))
n, bins, patches = plt.hist(old, zorder=2, edgecolor='k', density=True)

#add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - old.mean()))**2))

plt.plot(bins, y, '--', label=r'$\sigma={}$'.format(np.round(sigma, 4)))
plt.axvline(old.mean(), zorder=2, color='k', linestyle='dashed', label=r'$\mu={}$'.format(np.round(old.mean(), 4)))
plt.title("Frequency of Mean Rating Before Imputation, N=765", fontsize=16)
plt.xlabel("Mean Rating", fontsize=16)
plt.ylabel("Probability Density", fontsize=16)
plt.grid(zorder=0)
plt.legend()

# %% [markdown]
# ### Plot the mean of brewery ratings after impute

# %%
new = df_brewery_mean['Imputed']
sigma = np.std(new)

plt.figure(figsize=(12,6))
n, bins, patched = plt.hist(new, zorder=2, edgecolor='k', density=True)

#add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - new.mean()))**2))

plt.plot(bins, y, '--', label=r'$\sigma={}$'.format(np.round(sigma, 4)))
plt.axvline(new.mean(), zorder=2, color='k', linestyle='dashed', label=r'$\mu={}$'.format(np.round(new.mean(), 4)))
plt.title("Frequency of Mean Rating After Imputation, N=765", fontsize=16)
plt.xlabel("Mean Rating", fontsize=16)
plt.ylabel("Probability Density", fontsize=16)
plt.grid(zorder=0)
plt.legend()

# %% [markdown]
# #### As we can see after we impute all the data the the distribution of mean ratings gets much tighter. The standard deviation drops from 0.5284 to 0.0323. This is because before the imputation the reccomendation matrix is extremely sparse, so we get many outliers of breweries that were only reviewed very few times, so it is not a true estimate, thus increasing the standard deviation of the distribution

# %% [markdown]
# ## Compare means of beer styles before and after impute

# %%
original_styles = df_style_ratings.T
imputed_styles = fit_style_ratings.T

# %%
mean_style_comparison = np.ndarray((len(beer_styles), 3))
for idx, style in enumerate(beer_styles):
    old_mean = np.nanmean(original_styles[style])
    new_mean = np.mean(imputed_styles[style])
    change = np.abs(new_mean - old_mean)
    mean_style_comparison[idx, :] = (old_mean, new_mean, change)
    
df_style_mean = pd.DataFrame(mean_style_comparison, columns=['Old', 'Imputed', 'Change'])
df_style_mean.rename(index={idx: style for idx, style in enumerate(beer_styles)}, inplace=True)
df_style_mean.head()
# Out:
#                                      Old   Imputed    Change
# Hefeweizen                      3.987224  3.966740  0.020484
# English Strong Ale              3.686095  3.943536  0.257441
# Foreign / Export Stout          3.698737  3.928733  0.229996
# German Pilsener                 3.771591  3.941528  0.169937
# American Double / Imperial IPA  3.962265  3.954091  0.008174

# %%
average_style_rating_change = np.mean(df_style_mean['Change'])
std_style_rating_change = np.std(df_style_mean['Change'])
max_style_rating_change = max(df_style_mean['Change'])
min_style_rating_change = min(df_style_mean['Change'])
print(f'The average rating change for all styles was {np.round(average_style_rating_change, 4)} with a standard devation of {np.round(std_style_rating_change, 4)}')
print(f'The maximum rating change for all styles was {np.round(max_style_rating_change, 4)}')
print(f'The minimum rating change for all styles was {np.round(min_style_rating_change,4)}')
# Out:
# The average rating change for all styles was 0.2396 with a standard devation of 0.263
# The maximum rating change for all styles was 1.3591
# The minimum rating change for all styles was 0.0005

# %%
### find frequency of all breweries
freq = df_new[['beer_style']].value_counts()
y = list(df_style_mean['Change'])
x = []
for style in df_style_mean.index:
    x.append(int(freq[style]))

# %%
plt.figure(figsize=(12,6))
plt.scatter(x, y, zorder=2)
plt.title("Difference in Mean Rating Change After Impute for Each Style Compared to Number of Reviews", fontsize=16)
plt.ylabel("Difference", fontsize=16)
plt.xlabel("Number of Reviews", fontsize=16)
plt.grid(zorder=0)

# %% [markdown]
# #### As we can see from both the styles and breweries, the more reviews a certain brewery/style has the less likely its overall mean rating will change significantly.

# %% [markdown]
# ### Plot the average beer style rating before imputation

# %%
old = df_style_mean['Old']
sigma = np.std(old)

plt.figure(figsize=(12,6))
n, bins, patches = plt.hist(old, zorder=2, edgecolor='k', density=True)

#add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - old.mean()))**2))

plt.plot(bins, y, '--', label=r'$\sigma={}$'.format(np.round(sigma, 4)))
plt.axvline(old.mean(), zorder=2, color='k', linestyle='dashed', label=r'$\mu={}$'.format(np.round(old.mean(), 4)))
plt.title("Frequency of Mean Rating Before Imputation, N=103", fontsize=16)
plt.xlabel("Mean Rating", fontsize=16)
plt.ylabel("Probability Density", fontsize=16)
plt.grid(zorder=0)
plt.legend()

# %% [markdown]
# ### Plot the average beer style rating after imputation

# %%
new = df_style_mean['Imputed']
sigma = np.std(new)

plt.figure(figsize=(12,6))
n, bins, patched = plt.hist(new, zorder=2, edgecolor='k', density=True)

#add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - new.mean()))**2))

plt.plot(bins, y, '--', label=r'$\sigma={}$'.format(np.round(sigma, 4)))
plt.axvline(new.mean(), zorder=2, color='k', linestyle='dashed', label=r'$\mu={}$'.format(np.round(new.mean(), 4)))
plt.title("Frequency of Mean Rating After Imputation, N=103", fontsize=16)
plt.xlabel("Mean Rating", fontsize=16)
plt.ylabel("Probability Density", fontsize=16)
plt.grid(zorder=0)
plt.legend()

# %% [markdown]
# #### As we can see we get the same results as the breweries: a tighter distribution. We see that the standard deviation of the ratings decreases from 0.3103 to 0.0339

# %% [markdown]
# # Example Predictions using top 10 breweries and top 10 styles

# %%
reviewers = df_new['review_profilename'].value_counts()
print(reviewers.head())

top_reviewers = reviewers.index[:5]
# Out:
# northyorksammy    792
# womencantsail     617
# mikesgroove       590
# BuckeyeNation     484
# Thorpe429         478
# Name: review_profilename, dtype: int64
# Index(['northyorksammy', 'womencantsail', 'mikesgroove', 'BuckeyeNation',
#        'Thorpe429'],
#       dtype='object')

# %%
for reviewer in top_reviewers:
    print(f"({reviewer}) Beers you might like: \n")
    for style in fit_style_ratings[reviewer].sort_values(ascending=False).index[:10]:
        for brewery in fit_brewery_ratings[reviewer].sort_values(ascending=False).index[:10]:
            beer = list(df_new.loc[df_new['beer_style'] == style].loc[df_new['brewery_name'] == brewery].sort_values(by=['review_overall'], ascending=False)['beer_name'])

            if not len(beer) > 0:
                continue
            else:
                print(f'{beer[0]} by {brewery} ({style})')
                
    print('\n')
# Out:
# (northyorksammy) Beers you might like:
#
# 440 Pepper Smoker by Original Gravity Brewing Company (Chile Beer)
# Hakusekikan Shizen Bakushu by Stone Iwamoto Co., Ltd / Hakusekikan Beer Restaurant BACCHUS (Lambic - Unblended)
# Honey Badger by Cambridge Brewing Company (Lambic - Unblended)
# AleSmith Decadence 2009 Dunkel Weizenbock by AleSmith Brewing Company (Weizenbock)
# Alesmith Speedway Stout - Double Coffee by AleSmith Brewing Company (Russian Imperial Stout)
# YouEnjoyMyStout by Cambridge Brewing Company (Russian Imperial Stout)
# Resolution #9 by Cambridge Brewing Company (Flanders Oud Bruin)
# AleSmith Grand Cru Ale by AleSmith Brewing Company (Belgian Strong Dark Ale)
# Hakusekikan Brown Ale by Stone Iwamoto Co., Ltd / Hakusekikan Beer Restaurant BACCHUS (Belgian Strong Dark Ale)
# Off-(trap)Piste Belgian-Style Grand Cru by Cambridge Brewing Company (Belgian Strong Dark Ale)
#
#
# (womencantsail) Beers you might like:
#
# ...
